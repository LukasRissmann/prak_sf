# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
#read image
imgSRC =

# %%
#OPTIONAL: display image

# %%
#detect max x and y values of the image (use the shape of the image)

# %%
#initialize mask image with zeros, using the max x and y values

# %%
#convert image to HLS color space use cv2.COLOR_BGR2HLS
imgHLS =

# %%
#set lower and upper bounds for S and L
sLow = 
sHi = 
lLow = 
lHi =

# %%
#loop through all pixels and set mask to white if pixel is in the specified range

#loop over all pixels in X
for y in range():
    #loop over all pixels in Y
    for x in range():
        #get H, L, and S values for the current pixel
        H = 
        L = 
        S = 
        #check if the current pixel is in the specified range for S values
        if (sLow <= S and S <= sHi):
            if (lLow <= L and L <= lHi):
                #set mask pixel to white (255, 255, 255)

# %%
#set kernel for morphological operations (use np.ones() and np.uint8) 
kernel =

# %%
#erosion the masked image (use the kernel)
imgMSK =

# %%
#dilate the image (use the kernel)
imgMSK =

# %%
#erode the image again (use the kernel)
imgMSK =

# %%
#create result image by combining the masked image with the original image (use cv2.bitwise_and()
imgRST =

# %%
#create BGR image from result image (use cv2.COLOR_HLS2BGR)
imgBGR =

# %%
#OPTIONAL: display source image

# %%
#OPTIONAL: display mask image

# %%
#check if there is a contour within the mask
#first create  variable to store the result
contour_within_mask =

# %%
#convert image to grayscale (use cv2.COLOR_BGR2GRAY)
img =

# %%
#find contours in the greyscale image
contours, hierarchy =

# %%
#create a counter variable
i = 
#loop through all contours
for c in contours:
    #skip the first contour, because it is the whole image
    if i == 0:

    #check if the contour area is greater than 0
    #if so, there is a contour within the mask (use cv2.contourArea()

        #set contour_within_mask to True
        contour_within_mask = 
    #increase counter
    i +=

# %%
#print result
# Out:
# False
